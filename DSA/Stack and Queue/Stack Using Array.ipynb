# %%
## Implementation of Stack(LIFO) using Array
stack = []
stack.append('https://leetcode.com/')
stack.append('https://leetcode.com/problemset/')
stack.append('https://leetcode.com/discuss/')
stack.append('https://leetcode.com/contest/')

# %%
dir(stack)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
stack
# Out:
# ['https://leetcode.com/',
#  'https://leetcode.com/problemset/',
#  'https://leetcode.com/discuss/',
#  'https://leetcode.com/contest/']

# %%
stack.pop() #Last in First out
# Out:
# 'https://leetcode.com/contest/'

# %%
stack[-1]
# Out:
# 'https://leetcode.com/discuss/'

# %%
stack.pop() #Last in First out
# Out:
# 'https://leetcode.com/discuss/'

# %%
stack.pop() #Last in First out
# Out:
# 'https://leetcode.com/problemset/'

# %%
stack
# Out:
# ['https://leetcode.com/']

# %%
stack.pop()
# Out:
# 'https://leetcode.com/'
