# %%
## Implementation of Stack using LinkedList
from collections import deque
stack = deque()

# %%
dir(stack)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'appendleft',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'extendleft',
#  'index',
#  'insert',
#  'maxlen',
#  'pop',
#  'popleft',
#  'remove',
#  'reverse',
#  'rotate']

# %%
stack.append('https://github.com/NandiniYannagiri')
stack.append('https://github.com/NandiniYannagiri/DSA')
stack.append('https://github.com/NandiniYannagiri/DSA/blob/main/LinearSearch.ipynb')

# %%
stack
# Out:
# deque(['https://github.com/NandiniYannagiri',
#        'https://github.com/NandiniYannagiri/DSA',
#        'https://github.com/NandiniYannagiri/DSA/blob/main/LinearSearch.ipynb'])

# %%
stack.pop() # LIFo
# Out:
# 'https://github.com/NandiniYannagiri/DSA/blob/main/LinearSearch.ipynb'

# %%
stack[-1] # just returns the last element without deletion - same peek function do the same
          # but pop function delete the last element
# Out:
# 'https://github.com/NandiniYannagiri/DSA'

# %%
stack.pop()
# Out:
# 'https://github.com/NandiniYannagiri/DSA'

# %%
stack.pop()
# Out:
# 'https://github.com/NandiniYannagiri'

# %%
stack
# Out:
# deque([])

# %%
stack.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 stack.pop()
#
# IndexError: pop from an empty deque

# %%
## Implentation using class
