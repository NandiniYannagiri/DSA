# %%
HDFC_Mutual_Stock = []
#Enque(insertion) using Array
HDFC_Mutual_Stock.insert(0,10)
HDFC_Mutual_Stock.insert(0,40)
HDFC_Mutual_Stock.insert(0,5)

# %%
HDFC_Mutual_Stock
# Out:
# [5, 40, 10]

# %%
#deque(deletion)
HDFC_Mutual_Stock.pop()
# Out:
# 10

# %%
HDFC_Mutual_Stock.pop()
# Out:
# 40

# %%
HDFC_Mutual_Stock.pop()
# Out:
# 5

# %%
HDFC_Mutual_Stock.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 HDFC_Mutual_Stock.pop()
#
# IndexError: pop from empty list
