# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None
    ## insertion at end
    def InsertionAtEnd(self,new_data):
        new_node = Node(new_data)
        if self.head is None:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node
    def printList(self):
        temp = self.head
        while temp:
            print(str(temp.data)+" ", end=" ")
            temp =temp.next

    def InsertionAfterAnyNode(self,prev_node,new_data):
        if self.head is None:
            print("please insert data into LinkedList")
        # elif self.head.next = None:
        #     self.head.next = new_node
        # else:
        new_node = Node(new_data)
        new_node.next = prev_node.next
        prev_node.next = new_node
LList = LinkedList()
LList.InsertionAtEnd(2)
LList.InsertionAtEnd(4)
LList.InsertionAtEnd(5)
LList.InsertionAtEnd(10)
LList.printList()
print()
LList.InsertionAfterAnyNode(LList.head,12)
LList.printList()
print()
LList.InsertionAfterAnyNode(LList.head.next,1)
LList.printList()

print()
LList.InsertionAfterAnyNode(LList.head.next.next.next,165)
LList.printList()
print()
LList.InsertionAfterAnyNode(LList.head.next.next,132)
LList.printList()
# Out:
# 2  4  5  10
# 2  12  4  5  10
# 2  12  1  4  5  10
# 2  12  1  132  4  5  10
# 2  12  1  132  165  4  5  10
