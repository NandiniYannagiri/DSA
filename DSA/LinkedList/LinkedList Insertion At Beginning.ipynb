# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linkedlist:
    def __init__(self):
        self.head = None
    def insertAtFront(self,new_data):
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node
        # or (but no need to check, why because already you are taking self.head = None, means, you are taking empty LL 
        # new_node = Node(new_data)
        # if self.head is None:
        #     self.head = new_node
        # else:
        #     new_node.next = self.head
        #     self.head = new_node
    def printList(self):
        temp = self.head
        while temp:
            print(f'{temp.data} ',end = " ")
            # print(str(temp.data) + " ", end = " ")
            temp = temp.next
Llist = Linkedlist()
Llist.insertAtFront(12)
Llist.insertAtFront(9)
Llist.insertAtFront(7)
Llist.printList()
# Out:
# 7  9  12
