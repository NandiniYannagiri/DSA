# %%
## Bubble sort Implementation
## Time complexity O(n^2)
## Space complexity O(1) - no extra space is used
def BubbleSort(arr):
    for i in range(len(arr)):
        for j in range(i+1,len(arr)):
            if arr[i]>arr[j]:
                arr[i],arr[j] = arr[j],arr[i]
    return arr
arr = [42,12,4,6,22,41,77,3,78,9]
result = BubbleSort(arr)
print("sorted array after Bubble sorting Algorithm",result)
# Out:
# sorted array after Bubble sorting Algorithm [3, 4, 6, 9, 12, 22, 41, 42, 77, 78]
