# %%
class Solution(object):
#     def climbStairs(self, n):
#         """
#         :type n: int
#         :rtype: int
#         """
#        # Memoization - top down approach - time complexity O(n), space complexity O(n)
#         memo = [None] * (n + 1)
#         return self.climb_topDown(n, memo)
# # memoization
#     def climb_topDown(self,n, memo):
#         if memo[n] is not None:
#             return memo[n]
    
#         if n == 1 or n == 2:
#             result = n
#         else:
#             result = self.climb_topDown(n-1, memo) + self.climb_topDown(n-2, memo)
    
#         memo[n] = result
#         return result

# Tabulation approach
    def climbStairs(self, n):
        if n==1 or n==2:
            return n
        cs = [None]*(n+1)
        cs[1] = 1
        cs[2] = 2
        for i in range(3,n+1):
            cs[i] = cs[i-1]+cs[i-2]
        return cs[n]
