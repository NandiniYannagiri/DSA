# %%
import math
def JumpSearch(array,size,SearchingElement):
    step = int(math.sqrt(size))
    prev = 0
    for i in range(0,size,step):
        if array[i]==SearchingElement:
            return i
        elif array[i]>SearchingElement:
            prev = max(0,i-step)
            break
    else:
        prev = (size//step)*step
    # Linear Searh to find the index of searching element
    for i in range(prev,min(prev+step,size)):
        if array[i]==SearchingElement:
            return i
    return -1

arr = [2,4,5,7,8,9,13,21,32,42,45,50,67]
x = 4
n = len(arr)
index = jump_search(arr, n, x)
print(f"The element {x} is at index {index}")
# Out:
# The element 4 is at index 1
